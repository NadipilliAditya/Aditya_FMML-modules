# %% [markdown]
# <a href="https://colab.research.google.com/github/NadipilliAditya/Aditya_FMML-modules/blob/main/Module8_lab3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2025-03-14 16:08:02--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   244MB/s    in 0.3s
#
# 2025-03-14 16:08:04 (244 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 26049  1608.04337v2  Deep convolutional neural networks achieve rem...    cs
# 5561    1207.4597v1  A number of problems in statistical physics an...  stat
# 3297    1412.8380v2  Data vectors are obtained from multiple domain...  stat
# 32475   1211.1799v1  This paper presents algorithm for missing valu...    cs
# 40660   1207.5091v1  We consider the problem of learning a non-dete...    cs
# ...             ...                                                ...   ...
# 10442   1101.3594v2  This work is motivated by the problem of image...  stat
# 887    1508.04422v3  Several popular graph embedding techniques for...  stat
# 26519  1610.09736v3  Due to the potential risk of inducing cancers,...    cs
# 25328  1507.07096v1  The object recognition is a complex problem in...    cs
# 34048   1309.1536v2  We show that the Zipf's law for Chinese charac...    cs
#
#                                                    title  year  \
# 26049  Design of Efficient Convolutional Layers using...  2016
# 5561   Local stability of Belief Propagation algorith...  2012
# 3297   A simple coding for cross-domain matching with...  2014
# 32475  Algorithm for Missing Values Imputation in Cat...  2012
# 40660   Learning Probabilistic Systems from Tree Samples  2012
# ...                                                  ...   ...
# 10442  Classification under Data Contamination with A...  2011
# 887    Scalable Out-of-Sample Extension of Graph Embe...  2015
# 26519  A deep convolutional neural network using dire...  2016
# 25328  Thinning Algorithm Using Hypergraph Based Morp...  2015
# 34048     Rank-frequency relation for Chinese characters  2013
#
#                                                 keywords
# 26049  [convolutional, remarkable, recognition, perfo...
# 5561   [statistical, expressed, computation, probabil...
# 3297   [representations, different, different, dimens...
# 32475  [algorithm, imputation, categorical, algorithm...
# 40660  [deterministic, probabilistic, consistent, con...
# ...                                                  ...
# 10442  [motivated, registration, interested, determin...
# 887    [embedding, techniques, representation, dimens...
# 26519  [potential, radiation, artifacts, starvation, ...
# 25328  [recognition, processing, mathematical, morpho...
# 34048  [characters, perfectly, sufficiently, differen...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 26049    [convolutional, remarkable, recognition, perfo...
# 5561     [statistical, expressed, computation, probabil...
# 3297     [representations, different, different, dimens...
# 32475    [algorithm, imputation, categorical, algorithm...
# 40660    [deterministic, probabilistic, consistent, con...
#                                ...
# 21812    [embedding, algorithm, dimension, technique, c...
# 5451     [considers, embedding, euclidean, retaining, d...
# 22911    [algorithms, generating, distribution, algorit...
# 1788     [performances, convolutional, relatively, char...
# 22563    [personalized, treatment, increased, therapies...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8830 words.
# Out of those 4561 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="381404e7-c132-45ad-805a-0676377531ab" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("381404e7-c132-45ad-805a-0676377531ab")) {                    Plotly.newPlot(                        "381404e7-c132-45ad-805a-0676377531ab",                        [{"x":["remarkably","advantage","bottleneck","outperform","considered","respectively","sequentially","correlation","computation","complexity","connection","recognition","efficient","introduce","projection","remarkable","demonstrate","deconvolution","negligible","operation","structure","computational","topological","requiring","additionally","arranging","experiments","performance","simultaneously","performing","convolutional","convolution","sufficient","guaranteed","propagation","expressed","underlying","stability","algorithm","iterative","statistical","condition","approximate","marginals","popularity","understanding","probabilities","multivariate","augmented","representations","principal","association","mentioned","formulation","canonical","correspondence","illustrative","embarrassingly","classical","reduction","different","dimension","extension","discussed","numerical","dimensions","component","projected","concatenated","interesting","statistics","validation","regularization","approaches","explaining","parameter","distances","embedding","associative","proposing","transformations","categorical","presented","imputation","experimental","attribute","deterministic","equivalence","therefore","traditional","simulation","guarantee","probabilistic","consistency","stochastic","partitioning","conjecture","assumptions","algorithms","automated","generated","verification","resulting","hypothesis","intermediate","naturally","consistent","additional","framework","partitions","knowledgeable","undecidable","decidable","utilizing","generation","information","highlights","classification","summarization","experience","challenging","highlight","objective","independent","detection","generating","increasing","effective","attracted","movements","represent","outperforms","bidirectional","interaction","importance","interests","recurrent","extracted","techniques","conditions","suggested","variables","demonstrating","clusterings","comparing","phylogenetic","ensembling","particular","dissimilarity","alignment","sequences","technique","dimensional","explanatory","continues","clustering","averaging","architecture","individual","occupancy","resolution","autoencoders","representing","including","application","volumetric","representation","particularly","architectures","improving","highlighting","properties","intrinsic","morphology","associate","relations","procedure","morphologically","inexpensive","inflectional","constraints","difficulty","insensitivity","detrimental","evaluation","estimates","morphological","derivational","frequency","signatures","expensive","downstream","languages","distributional","collection","phenomena","penalization","continuous","generalization","graphical"],"y":[15,96,15,96,132,89,11,76,138,237,44,392,414,339,39,25,551,9,10,50,322,277,19,56,63,2,594,889,104,72,400,50,63,30,72,39,111,32,789,75,167,47,93,1,23,169,62,20,44,238,34,30,17,78,24,22,6,1,104,89,746,60,69,61,77,34,88,22,7,73,66,56,95,420,17,126,24,99,4,23,45,12,190,6,360,31,50,20,138,181,88,27,169,66,115,11,9,68,585,79,154,40,160,58,36,57,83,119,525,9,2,5,3,47,155,678,14,494,36,31,241,42,132,124,340,87,113,246,28,14,118,285,28,85,84,8,159,113,392,140,20,136,26,4,76,4,3,264,6,52,95,257,176,2,8,165,21,254,118,7,101,11,60,266,246,13,341,68,111,97,14,215,27,19,10,93,119,8,10,4,148,49,2,2,254,74,28,4,58,6,64,7,91,28,62,30,1,103,102,53],"type":"bar"},{"x":["remarkably","advantage","bottleneck","outperform","considered","respective ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4561,), (4561, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8058333333333333

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Learning</span> <span style=''>Linear</span> <span style=''>Feature</span> <span style=''>Space</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Transformations</span> <span style=''>in</span> <span style=''>Symbolic</span> <span style='background-color:rgba(255, 0, 0, 0.5164835164835165);'>Regression</span> <br/><br/><span style=''>We</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>new</span> <span style=''>type</span> <span style=''>of</span> <span style=''>leaf</span> <span style=''>node</span> <span style=''>for</span> <span style=''>use</span> <span style=''>in</span> <span style=''>Symbolic</span> <span style='background-color:rgba(255, 0, 0, 0.5164835164835165);'>Regression</span> <span style=''>(SR)</span> <span style=''>that</span> <span style=''>performs</span> <span style=''>linear</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>combinations</span> <span style=''>of</span> <span style=''>feature</span> <span style='background-color:rgba(255, 0, 0, 0.3539192399049881);'>variables</span> <span style=''>(LCF)</span> <span style=''>These</span> <span style=''>nodes</span> <span style=''>can</span> <span style=''>be</span> <span style=''>handled</span> <span style=''>in</span> <span style=''>three</span> <span style='background-color:rgba(0, 255, 0, 0.31569664902998235);'>different</span> <span style=''>modes</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>unsynchronized</span> <span style=''>mode</span> <span style=''>where</span> <span style=''>all</span> <span style=''>LCFs</span> <span style=''>are</span> <span style=''>free</span> <span style=''>to</span> <span style=''>change</span> <span style=''>on</span> <span style=''>their</span> <span style=''>own</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.4999999999999999);'>synchronized</span> <span style=''>mode</span> <span style=''>where</span> <span style=''>LCFs</span> <span style=''>are</span> <span style=''>sorted</span> <span style=''>into</span> <span style=''>groups</span> <span style=''>in</span> <span style=''>which</span> <span style=''>they</span> <span style=''>are</span> <span style=''>forced</span> <span style=''>to</span> <span style=''>be</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>identical</span> <span style='background-color:rgba(0, 255, 0, 0.4210526315789474);'>throughout</span> <span style=''>the</span> <span style=''>whole</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>individual</span> <span style=''>and</span> <span style=''>a</span> <span style=''>globally</span> <span style='background-color:rgba(0, 255, 0, 0.4999999999999999);'>synchronized</span> <span style=''>mode</span> <span style=''>which</span> <span style=''>is</span> <span style=''>similar</span> <span style=''>to</span> <span style=''>the</span> <span style=''>previous</span> <span style=''>mode</span> <span style=''>but</span> <span style=''>the</span> <span style=''>grouping</span> <span style=''>is</span> <span style=''>done</span> <span style=''>across</span> <span style=''>the</span> <span style=''>whole</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>population</span> <span style=''>We</span> <span style=''>also</span> <span style=''>present</span> <span style=''>two</span> <span style=''>methods</span> <span style=''>of</span> <span style=''>evolving</span> <span style=''>the</span> <span style=''>weights</span> <span style=''>of</span> <span style=''>the</span> <span style=''>LCFs</span> <span style=''>a</span> <span style=''>purely</span> <span style='background-color:rgba(255, 0, 0, 0.42065491183879095);'>stochastic</span> <span style=''>way</span> <span style=''>via</span> <span style=''>mutation</span> <span style=''>and</span> <span style=''>a</span> <span style=''>gradient</span> <span style=''>based</span> <span style=''>way</span> <span style=''>based</span> <span style=''>on</span> <span sty ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Flexible</span> <span style=''>High</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensional</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Classification</span> <span style=''>Machines</span> <span style=''>and</span> <span style=''>Their</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Asymptotic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Properties</span> <br/><br/><span style='background-color:rgba(255, 0, 0, 0.3);'>Classification</span> <span style=''>is</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>important</span> <span style=''>topic</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>statistics</span> <span style=''>and</span> <span style=''>machine</span> <span style=''>learning</span> <span style=''>with</span> <span style=''>great</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>potential</span> <span style=''>in</span> <span style=''>many</span> <span style=''>real</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>applications</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>investigate</span> <span style=''>two</span> <span style=''>popular</span> <span style=''>large</span> <span style=''>margin</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classification</span> <span style=''>methods</span> <span style=''>Support</span> <span style=''>Vector</span> <span style=''>Machine</span> <span style=''>(SVM)</span> <span style=''>and</span> <span style=''>Distance</span> <span style=''>Weighted</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Discrimination</span> <span style=''>(DWD)</span> <span style=''>under</span> <span style=''>two</span> <span style=''>contexts</span> <span style=''>the</span> <span style=''>high</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensional</span> <span style=''>low</span> <span style=''>sample</span> <span style=''>size</span> <span style=''>data</span> <span style=''>and</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>imbalanced</span> <span style=''>data</span> <span style=''>A</span> <span style=''>unified</span> <span style=''>family</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classification</span> <span style=''>machines</span> <span style=''>the</span> <span style=''>FLexible</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Assortment</span> <span style=''>MachinE</span> <span style=''>(FLAME)</span> <span style=''>is</span> <span style=''>proposed</span> <span style=''>within</span> <span style=''>which</span> <span style=''>DWD</span> <span style=''>and</span> <span style=''>SVM</span> <span style=''>are</span> <span style=''>special</span> <span style=''>cases</span> <span style=''>The</span> <span style=''>FLAME</span> <span style=''>family</span> <span style=''>helps</span> <span style=''>to</span> <span style=''>identify</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>similarities</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>differences</span> <span style=''>between</span> <span style=''>SVM</span> <span style=''>and</span> <span style=''>DWD</span> <span style=''>It</span> <span style=''>is</span> <span style=''>well</span> <span style=''>known</span> <span style=''>that</span> <span style=''>many</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>classifiers</span> <span style=''>overfit</span> <span style=''>the</span> <span style=''>data</span> <span style=''>in</span> <span style=''>the</span> <span style=''>high</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensional</span> <span style=''>setting</span> <span style=''>and</span> <span style=''>others</span> <span ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Fast</span> <span style=''>spectral</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style=''>from</span> <span style=''>sum</span> <span style=''>of</span> <span style=''>squares</span> <span style=''>proofs</span> <span style=''>tensor</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>decomposition</span> <span style=''>and</span> <span style=''>planted</span> <span style=''>sparse</span> <span style=''>vectors</span> <br/><br/><span style=''>We</span> <span style=''>consider</span> <span style=''>two</span> <span style=''>problems</span> <span style=''>that</span> <span style=''>arise</span> <span style=''>in</span> <span style=''>machine</span> <span style=''>learning</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>applications</span> <span style=''>the</span> <span style=''>problem</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>recovering</span> <span style=''>a</span> <span style=''>planted</span> <span style=''>sparse</span> <span style=''>vector</span> <span style=''>in</span> <span style=''>a</span> <span style=''>random</span> <span style=''>linear</span> <span style=''>subspace</span> <span style=''>and</span> <span style=''>the</span> <span style=''>problem</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>decomposing</span> <span style=''>a</span> <span style=''>random</span> <span style=''>low</span> <span style=''>rank</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>overcomplete</span> <span style=''>3</span> <span style=''>tensor</span> <span style=''>For</span> <span style=''>both</span> <span style=''>problems</span> <span style=''>the</span> <span style=''>best</span> <span style=''>known</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>guarantees</span> <span style=''>are</span> <span style=''>based</span> <span style=''>on</span> <span style=''>the</span> <span style=''>sum</span> <span style=''>of</span> <span style=''>squares</span> <span style=''>method</span> <span style=''>We</span> <span style=''>develop</span> <span style=''>new</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style=''>inspired</span> <span style=''>by</span> <span style=''>analyses</span> <span style=''>of</span> <span style=''>the</span> <span style=''>sum</span> <span style=''>of</span> <span style=''>squares</span> <span style=''>method</span> <span style=''>Our</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style=''>achieve</span> <span style=''>the</span> <span style=''>same</span> <span style=''>or</span> <span style=''>similar</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>guarantees</span> <span style=''>as</span> <span style=''>sum</span> <span style=''>of</span> <span style=''>squares</span> <span style=''>for</span> <span style=''>these</span> <span style=''>problems</span> <span style=''>but</span> <span style=''>the</span> <span style=''>running</span> <span style=''>time</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>significantly</span> <span style=''>faster</span> <span style=''>For</span> <span style=''>the</span> <span style=''>planted</span> <span style=''>sparse</span> <span style=''>vector</span> <span style=''>problem</span> <span style=''>we</span> <span style=''>give</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>with</span> <span style=''>running</span> <span style=''>time</span> <span style=''>nearly</span> <span style=''>linear</span> <span style=''>in</span> <span style=''>the</span> <span style=''>input</span> <span style=''>size</span> <span style=''>that</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>approximately</span> <span style=''>recovers</span> <span style=''>a</span> <span style=''>planted</span> <span style=''>sparse</span> < ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Are</span> <span style=''>Saddles</span> <span style=''>Good</span> <span style=''>Enough</span> <span style=''>for</span> <span style=''>Deep</span> <span style=''>Learning</span> <br/><br/><span style=''>Recent</span> <span style=''>years</span> <span style=''>have</span> <span style=''>seen</span> <span style=''>a</span> <span style=''>growing</span> <span style=''>interest</span> <span style=''>in</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>understanding</span> <span style=''>deep</span> <span style=''>neural</span> <span style=''>networks</span> <span style=''>from</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>optimization</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>perspective</span> <span style=''>It</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>understood</span> <span style=''>now</span> <span style=''>that</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>converging</span> <span style=''>to</span> <span style=''>low</span> <span style=''>cost</span> <span style=''>local</span> <span style=''>minima</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>sufficient</span> <span style=''>for</span> <span style=''>such</span> <span style=''>models</span> <span style=''>to</span> <span style=''>become</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>effective</span> <span style=''>in</span> <span style=''>practice</span> <span style=''>However</span> <span style=''>in</span> <span style=''>this</span> <span style=''>work</span> <span style=''>we</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>new</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>hypothesis</span> <span style=''>based</span> <span style=''>on</span> <span style=''>recent</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>theoretical</span> <span style=''>findings</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>empirical</span> <span style=''>studies</span> <span style=''>that</span> <span style=''>deep</span> <span style=''>neural</span> <span style=''>network</span> <span style=''>models</span> <span style=''>actually</span> <span style=''>converge</span> <span style=''>to</span> <span style=''>saddle</span> <span style=''>points</span> <span style=''>with</span> <span style=''>high</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>degeneracy</span> <span style=''>Our</span> <span style=''>findings</span> <span style=''>from</span> <span style=''>this</span> <span style=''>work</span> <span style=''>are</span> <span style=''>new</span> <span style=''>and</span> <span style=''>can</span> <span style=''>have</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>significant</span> <span style=''>impact</span> <span style=''>on</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>development</span> <span style=''>of</span> <span style=''>gradient</span> <span style=''>descent</span> <span style=''>based</span> <span style=''>methods</span> <span style=''>for</span> <span style=''>training</span> <span style=''>deep</span> <span style=''>networks</span> <span style=''>We</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>validated</span> <span style=''>our</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>hypotheses</span> <span style=''>using</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>extensive</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>experimental</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>evaluation</span> <span style=''>on</span> <span style=''>standard</span> <span style=''>datasets</span> <span style=''>such</span> <span style=''>as</span> <span style=''>MNIST</span> <span style=''>and</span> <span style=''>CIFAR</span> <span style=' ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	representation (0.12100780695528744)
# 	experimental (0.127750177430802)
# 	processing (0.10042583392476934)
# 	information (0.24059616749467708)
# 	architecture (0.09013484740951029)
# 	segmentation (0.07629524485450674)
# 	detection (0.12065294535131299)
# 	different (0.26472675656493966)
# 	convolutional (0.14194464158977999)
# 	recognition (0.1391057487579844)
#
# Some Statistics words are:
# 	statistical (0.14783047426841575)
# 	theoretical (0.14783047426841575)
# 	variables (0.1437941473259334)
# 	stochastic (0.14228052472250252)
# 	algorithm (0.38799192734611504)
# 	estimation (0.18314833501513622)
# 	distribution (0.17961654894046417)
# 	inference (0.198284561049445)
# 	dimensional (0.18970736629667004)
# 	regression (0.17406659939455096)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="182d9520-f9b5-42e4-a997-8fd609ba0f84" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("182d9520-f9b5-42e4-a997-8fd609ba0f84")) {                    Plotly.newPlot(                        "182d9520-f9b5-42e4-a997-8fd609ba0f84",                        [{"x":["remarkably","advantage","bottleneck","outperform","considered","respectively","sequentially","correlation","computation","complexity","connection","recognition","efficient","introduce","projection","remarkable","demonstrate","deconvolution","negligible","operation","structure","computational","topological","requiring","additionally","arranging","experiments","performance","simultaneously","performing","convolutional","convolution","sufficient","guaranteed","propagation","expressed","underlying","stability","algorithm","iterative","statistical","condition","approximate","marginals","popularity","understanding","probabilities","multivariate","augmented","representations","principal","association","mentioned","formulation","canonical","correspondence","illustrative","embarrassingly","classical","reduction","different","dimension","extension","discussed","numerical","dimensions","component","projected","concatenated","interesting","statistics","validation","regularization","approaches","explaining","parameter","distances","embedding","associative","proposing","transformations","categorical","presented","imputation","experimental","attribute","deterministic","equivalence","therefore","traditional","simulation","guarantee","probabilistic","consistency","stochastic","partitioning","conjecture","assumptions","algorithms","automated","generated","verification","resulting","hypothesis","intermediate","naturally","consistent","additional","framework","partitions","knowledgeable","undecidable","decidable","utilizing","generation","information","highlights","classification","summarization","experience","challenging","highlight","objective","independent","detection","generating","increasing","effective","attracted","movements","represent","outperforms","bidirectional","interaction","importance","interests","recurrent","extracted","techniques","conditions","suggested","variables","demonstrating","clusterings","comparing","phylogenetic","ensembling","particular","dissimilarity","alignment","sequences","technique","dimensional","explanatory","continues","clustering","averaging","architecture","individual","occupancy","resolution","autoencoders","representing","including","application","volumetric","representation","particularly","architectures","improving","highlighting","properties","intrinsic","morphology","associate","relations","procedure","morphologically","inexpensive","inflectional","constraints","difficulty","insensitivity","detrimental","evaluation","estimates","morphological","derivational","frequency","signatures","expensive","downstream","languages","distributional","collection","phenomena","penalization","continuous","generalization","graphical","symmetric","parametrization","construct","estimators","variational","exploration","triggered","divergence","perturbation","enumerated","inference","reparameterization","perturbative","divergences","processes","likelihoods","tightness","likelihood","determines","gradients","generalized","converges","covariances","posterior","estimating","capturing","periodicity","processing","important","animations","furthermore","precisely","recording","typically","interpolation","postprocessing","character","incorporating","characters","specificity","milestones","determine","constructed","sensitivity","conclusions","implications","represents","categorize","degeneration","distinguish","coherence","classifying","endpoints","extraction","diagnosis ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	perturbative
# 	covariances
# 	meaningfully
# 	contamination
# 	uncontaminated
# 	confounders
# 	dependences
# 	parsimony
# 	administrative
# 	submanifold
# 	misclassify
# 	supermodular
# 	assimilating
# 	assimilated
# 	oscillates
# 	offerings
# 	accompanies
# 	gaussianity
# 	expectimax
# 	encompass
# Some words which never appear in Statistics papers:
# 	arranging
# 	knowledgeable
# 	undecidable
# 	decidable
# 	morphologically
# 	inflectional
# 	derivational
# 	animations
# 	preliminarily
# 	illumination
# 	penultimate
# 	obstructive
# 	primitive
# 	upsampling
# 	stratification
# 	infrequently
# 	ecological
# 	ecosystems
# 	suppressed
# 	networked

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.0542744571027155e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7608333333333334
